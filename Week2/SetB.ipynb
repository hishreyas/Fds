# %%
#Name:Atharva Billampalli
#Roll no:12
#Assignment 1 Set B
#Question 1
import pandas as pd
df = pd.read_csv ('data.csv')
print("First 10 rows");
print(df.head(10))
print("Last 10 rows");
print(df.tail(10))
sample=df.sample(20);
print("random 20 sample")
sample
# Out:
# First 10 rows
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971
# 5      6        68.69784        123.3024
# 6      7        69.80204        141.4947
# 7      8        70.01472        136.4623
# 8      9        67.90265        112.3723
# 9     10        66.78236        120.6672
# Last 10 rows
#        Index  Height(Inches)  Weight(Pounds)
# 24990  24991        69.97767        125.3672
# 24991  24992        71.91656        128.2840
# 24992  24993        70.96218        146.1936
# 24993  24994        66.19462        118.7974
# 24994  24995        67.21126        127.6603
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# ...

# %%
#Question 2
print(df.shape)
print(df.size)
print (df.dtypes);
# Out:
# (25000, 3)
# 75000
# Index               int64
# Height(Inches)    float64
# Weight(Pounds)    float64
# dtype: object

# %%
#Question 3
print(df.describe())
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
#Question 4
print ('Observation:',df.size)
print('Missing value:',df.isnull().values.sum())
print ('Nan value:',df.isna().values.sum())
# Out:
# Observation: 75000
# Missing value: 0
# Nan value: 0

# %%
#Question 5
df['BMI']=(df['Weight(Pounds)']*0.453592)/(((df['Height(Inches)'])*0.0254)**2)
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)        BMI
# 0          1        65.78331        112.9925  18.357609
# 1          2        71.51521        136.4873  18.762615
# 2          3        69.39874        153.0269  22.338940
# 3          4        68.21660        142.3354  21.504569
# 4          5        67.78781        144.2971  22.077625
# ...      ...             ...             ...        ...
# 24995  24996        69.50215        118.0312  17.179016
# 24996  24997        64.54826        120.1932  20.281906
# 24997  24998        64.69855        118.2655  19.864010
# 24998  24999        67.52918        132.2682  20.392499
# 24999  25000        68.87761        124.8742  18.506084
#
# [25000 rows x 4 columns]

# %%
#Question 6
print("Max ", df["BMI"].max())
print("Min ", df["BMI"].min())
# Out:
# Max  26.023703378734265
# Min  13.070852401940636

# %%
#Question 7
import numpy as np
import matplotlib.pyplot as plt
df.plot.scatter(x="Height(Inches)",y="Weight(Pounds)")
plt.show()
# Out:
# /data/data/com.termux/files/usr/lib/python3.10/site-packages/matplotlib/bezier.py:216: RuntimeWarning: divide by zero encountered in power
#   return (np.power.outer(1 - t, self._orders[::-1])
# /data/data/com.termux/files/usr/lib/python3.10/site-packages/matplotlib/bezier.py:217: RuntimeWarning: divide by zero encountered in power
#   * np.power.outer(t, self._orders)) @ self._px
