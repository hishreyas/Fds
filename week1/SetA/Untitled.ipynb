# %%
#Name-Atharva Billampalli
#Roll no-12
#Foundation of Data science Assignment 1
import pandas as pd
df = pd.DataFrame(columns = ['Name','Age','Percentage'])
df.loc[1] = ['Raj ',25 ,67]
df.loc[2] = ['Sachin ',19 ,87]
df.loc[3] = ['Prathamesh ',17 ,55]
df.loc[4] = ['Shreyas ', 18,65]
df.loc[5] = ['Savan ', 20,95]
df.loc[6] = ['Mahesh', 19,88]
df.loc[7] = ['Ram ', 25,72]
df.loc[8] = ['Sahish ',24 ,62]
df.loc[9] = ['Rutik ', 14,51]
df.loc[10] = ['Aditya ', 13,45]
df
# Out:
#            Name Age Percentage
# 1          Raj   25         67
# 2       Sachin   19         87
# 3   Prathamesh   17         55
# 4      Shreyas   18         65
# 5        Savan   20         95
# 6        Mahesh  19         88
# 7          Ram   25         72
# 8       Sahish   24         62
# 9        Rutik   14         51
# 10      Aditya   13         45

# %%
#Question 2
import pandas as pd
df = pd.DataFrame(columns = ['Name','Age','Percentage'])
df.loc[1] = ['Raj ',25 ,67]
df.loc[2] = ['Sachin ',19 ,87]
df.loc[3] = ['Prathamesh ',17 ,55]
df.loc[4] = ['Sagar ', 18,65]
df.loc[5] = ['Savan ', 20,95]
df.loc[6] = ['Shreyas ', 19,88]
df.loc[7] = ['Ram ', 25,72]
df.loc[8] = ['God ',24 ,62]
df.loc[9] = ['Rutik ', 14,51]
df.loc[10] = ['Aditya ', 13,45]
print("\nShape\n")
print(df.shape)
print("\nDescribe\n")
print(df.describe())
print("\nData types \n")
print(df.dtypes)
print("\n Row and Columns")
print(df.size)
# Out:
# Shape
#
# (10, 3)
#
# Describe
#
#         Name  Age  Percentage
# count     10   10          10
# unique    10    8          10
# top     Raj    25          67
# freq       1    2           1
#
# Data types
#
# Name          object
# Age           object
# Percentage    object
# dtype: object
#
#  Row and Columns
# 30

# %%
#Question 3
import pandas as pd
df = pd.DataFrame(columns = ['Name','Age','Percentage'])
df.loc[1] = ['Raj ',25 ,67]
df.loc[2] = ['Sachin ',19 ,87]
df.loc[3] = ['Prathamesh ',17 ,55]
df.loc[4] = ['Sagar ', 18,65]
df.loc[5] = ['Swarup ', 20,95]
df.loc[6] = ['Anant ', 19,88]
df.loc[7] = ['Ram ', 25,72]
df.loc[8] = ['Shreyas ',24 ,62]
df.loc[9] = ['God ', 14,51]
df.loc[10] = ['Aditya ', 13,45]
print("\n Basic statistical details\n")
print(df.describe())
# Out:
#  Basic statistical details
#
#         Name  Age  Percentage
# count     10   10          10
# unique    10    8          10
# top     Raj    25          67
# freq       1    2           1

# %%
#Question 4
import pandas as pd
df = pd.DataFrame(columns = ['Name','Age','Percentage'])
df.loc[1] = ['Raj ',25 ,67]
df.loc[2] = ['Sachin ',19 ,87]
df.loc[3] = ['Prathamesh ',None ,55]
df.loc[4] = ['Sagar ', 18,65]
df.loc[5] = ['Swarup ', 20,95]
df.loc[6] = [None,25 ,67]
df.loc[7] = ['Shreyas ',87,None]
df.loc[8] = ['Prathamesh ',None,17]
df.loc[9] = ['Sagar ',18,65]
df.loc[10] = ['Ayushi ',None,95]
df.insert(len(df.columns),'Remarks',None)
print("\n Data\n")
df
# Out:
#  Data
#            Name   Age Percentage Remarks
# 1          Raj     25         67    None
# 2       Sachin     19         87    None
# 3   Prathamesh   None         55    None
# 4        Sagar     18         65    None
# 5       Swarup     20         95    None
# 6           NaN  25.0       67.0    None
# 7      Shreyas     87       None    None
# 8   Prathamesh   None         17    None
# 9        Sagar     18         65    None
# 10      Ayushi   None         95    None

# %%
#Question 5
import pandas as pd
df = pd.DataFrame(columns = ['Name','Age','Percentage'])
df.loc[1] = ['Raj ',25 ,67]
df.loc[2] = ['Sachin ',19 ,87]
df.loc[3] = ['Prathamesh ',None ,55]
df.loc[4] = ['Sagar ', 18,65]
df.loc[5] = ['Swarup ', 20,95]
df.loc[6] = [None,25 ,67]
df.loc[7] = ['Sachin ',87,None]
df.loc[8] = ['Prathamesh ',None,17]
df.loc[9] = ['Sagar ',18,65]
df.loc[10] = ['Swarup ',None,95]
df.insert(len(df.columns),'Remarks',None)
print("\n Data\n")
df
# Out:
#  Data
#            Name   Age Percentage Remarks
# 1          Raj     25         67    None
# 2       Sachin     19         87    None
# 3   Prathamesh   None         55    None
# 4        Sagar     18         65    None
# 5       Swarup     20         95    None
# 6           NaN  25.0       67.0    None
# 7       Sachin     87       None    None
# 8   Prathamesh   None         17    None
# 9        Sagar     18         65    None
# 10      Swarup   None         95    None

# %%
#Question 6
import pandas as pd
df = pd.DataFrame(columns = ['Name','Age','Percentage'])
df.loc[1] = ['Raj ',25 ,67]
df.loc[2] = ['Sachin ',19 ,87]
df.loc[3] = ['Prathamesh ',None ,55]
df.loc[4] = ['Sagar ',18,65]
df.loc[5] = ['Swarup ', 20,95]
df.loc[6] = [None,25 ,67]
df.loc[7] = ['Sachin ',19,87]
df.loc[8] = ['Shreyas',None,17]
df.loc[9] = ['God ',17,65]
df.loc[10] = ['Swarup ',None,95]
df.loc[11] = ['Raj ',25 ,67]
df.loc[12] = ['Swarup ', 20,95]
df.insert(len(df.columns),'Remarks',None)
df.drop(columns='Remarks',inplace=True)
df.drop_duplicates(inplace=True)
df
# Out:
#            Name   Age Percentage
# 1          Raj     25         67
# 2       Sachin     19         87
# 3   Prathamesh   None         55
# 4        Sagar     18         65
# 5       Swarup     20         95
# 6           NaN  25.0       67.0
# 8       Shreyas  None         17
# 9          God     17         65
# 10      Swarup   None         95

# %%
#Question 7
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame(columns = ['Name','Age','Percentage'])
df.loc[1] = ['Raj ',25 ,67]
df.loc[2] = ['Sachin ',19 ,87]
df.loc[3] = ['Prathamesh ',None ,55]
df.loc[4] = ['Sagar ',18,65]
df.loc[5] = ['Swarup ', 20,95]
df.loc[6] = [None,25 ,67]
df.loc[7] = ['Sachin ',19,87]
df.loc[8] = ['Prathamesh ',None,17]
df.loc[9] = ['Sagar ',18,65]
df.loc[10] = ['Swarup ',None,95]
df.loc[11] = ['Raj ',25 ,67]
df.loc[12] = ['Swarup ', 20,95]
df.plot(x="Name",y="Percentage")
plt.show()

# %%
#Question 8
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.DataFrame(columns = ['Name','Age','Percentage'])
df.loc[1] = ['Prathamesh',20 ,96]
df.loc[2] = ['sachin',23,87]
df.loc[3] = ['Rutik',21 ,94]
df.loc[4] = ['Ram ', 18, 72]
df.loc[5] = ['sahil ', 24,91]
df.loc[6] = [' sagar', 21,88]
df.loc[7] = ['Shreyash',25,68]
df.loc[8] = ['RAJ ',22 ,82]
df.loc[9] = ['RAGAV ', 23, 78]
df.loc[10] = ['Deva ', 17,70]
df.plot.scatter(x= "Name", y = "Percentage")
plt.show()
# Out:
# /data/data/com.termux/files/usr/lib/python3.9/site-packages/matplotlib/bezier.py:216: RuntimeWarning: divide by zero encountered in power
#   return (np.power.outer(1 - t, self._orders[::-1])
# /data/data/com.termux/files/usr/lib/python3.9/site-packages/matplotlib/bezier.py:217: RuntimeWarning: divide by zero encountered in power
#   * np.power.outer(t, self._orders)) @ self._px
